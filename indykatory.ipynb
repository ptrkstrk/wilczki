# %%
import wbgapi as wb
import pandas as pd

indicators = ['NY.GNP.PCAP.PP.CD',
'SE.XPD.PRIM.PC.ZS',
'SE.XPD.SECO.PC.ZS',
'SE.XPD.TERT.PC.ZS',
'IC.FRM.FEMO.ZS',
'IC.REG.PROC.FE',
'IC.REG.PROC.MA',
'SL.TLF.CACT.FE.ZS',
'SL.TLF.CACT.MA.ZS',
'SL.EMP.MPYR.FE.ZS',
'SL.EMP.MPYR.MA.ZS',
'AG.LND.AGRI.ZS',
'AG.LND.TOTL.K2',
'PER_ALLSP.BEN_Q1_',
'SL.UEM.TOTL.ZS',
'EN.POP.SLUM.UR.ZS',
'SI.DST.FRST.10']

time = range(2014, 2017)

data = wb.data.DataFrame(indicators, time=time, skipBlanks=False, labels=True, columns='series').reset_index().drop('time', axis=1)
data
# Out:
#     economy                      Country  Time  AG.LND.AGRI.ZS  \
# 0       ZWE                     Zimbabwe  2016       41.876696
# 1       ZWE                     Zimbabwe  2015       41.876696
# 2       ZWE                     Zimbabwe  2014       41.876696
# 3       ZMB                       Zambia  2016       32.063923
# 4       ZMB                       Zambia  2015       32.063923
# ..      ...                          ...   ...             ...
# 793     AFW   Africa Western and Central  2015       39.547318
# 794     AFW   Africa Western and Central  2014       39.520843
# 795     AFE  Africa Eastern and Southern  2016       43.901452
# 796     AFE  Africa Eastern and Southern  2015       43.772496
# 797     AFE  Africa Eastern and Southern  2014       43.674175
#
#      AG.LND.TOTL.K2  EN.POP.SLUM.UR.ZS  IC.FRM.FEMO.ZS  IC.REG.PROC.FE  \
# 0      3.868500e+05          22.758920            42.5       10.000000
# ...

# %%
data.to_csv('indicators.csv', index=False)
